# %%
import pandas as pd

# %% [markdown]
# # OUR WORLD IN DATA DATA

# %%
owid1 = pd.read_csv('./our_world_in_data/cost-healthy-diet-owid-2017-2021.csv')
owid1.head()
# Out:
#     Entity Code  Year  Cost of a healthy diet
# 0  Albania  ALB  2017                   3.952
# 1  Albania  ALB  2018                   4.069
# 2  Albania  ALB  2019                   4.262
# 3  Albania  ALB  2020                   4.280
# 4  Albania  ALB  2021                   4.388

# %%
owid1.shape
# Out:
# (885, 4)

# %%
owid2 = pd.read_csv('./our_world_in_data/cost-healthy-diet-share-food-expenditure-owid-2017.csv')
owid2.head()
# Out:
#                 Entity Code  Year  \
# 0              Albania  ALB  2017
# 1              Algeria  DZA  2017
# 2               Angola  AGO  2017
# 3             Anguilla  AIA  2017
# 4  Antigua and Barbuda  ATG  2017
#
#    Affordability of a healthy diet: ratio of cost to food expenditures
# 0                                          42.500000
# 1                                          60.500000
# 2                                          97.200000
# 3                                          57.700000
# 4                                          76.700005

# %%
owid2.shape
# Out:
# (181, 4)

# %%
owid3 = pd.read_csv('./our_world_in_data/number-healthy-diet-unaffordable-owid-2017-2021.csv')
owid3.head()
# Out:
#     Entity Code  Year  Number of people who cannot afford a healthy diet
# 0  Albania  ALB  2017                                           900000.0
# 1  Albania  ALB  2018                                           700000.0
# 2  Albania  ALB  2019                                           600000.0
# 3  Albania  ALB  2020                                           600000.0
# 4  Albania  ALB  2021                                           400000.0

# %%
owid3.shape
# Out:
# (763, 4)

# %%
owid4 = pd.read_csv('./our_world_in_data/share-healthy-diet-unaffordable-owid-2017-2021.csv')
owid4.head()
# Out:
#     Entity Code  Year  \
# 0  Albania  ALB  2017
# 1  Albania  ALB  2018
# 2  Albania  ALB  2019
# 3  Albania  ALB  2020
# 4  Albania  ALB  2021
#
#    Share of the population who cannot afford a healthy diet
# 0                                               31.3
# 1                                               23.0
# 2                                               22.2
# 3                                               19.9
# 4                                               15.9

# %%
owid4.shape
# Out:
# (763, 4)

# %%
### MERGE THESE 4 OWID datasets above? 
# could merge 1, 3, and 4... 2 only has 2017

# %%
owid1 = pd.DataFrame(owid1)
owid2 = pd.DataFrame(owid2)

owid_cost = pd.merge(owid1, owid2, on=['Entity', 'Code', 'Year'], how='left')
owid_cost = pd.DataFrame(owid_cost)

# %%
owid_cost.shape
# Out:
# (885, 5)

# %%
owid_cost.head()
# Out:
#     Entity Code  Year  Cost of a healthy diet  \
# 0  Albania  ALB  2017                   3.952
# 1  Albania  ALB  2018                   4.069
# 2  Albania  ALB  2019                   4.262
# 3  Albania  ALB  2020                   4.280
# 4  Albania  ALB  2021                   4.388
#
#    Affordability of a healthy diet: ratio of cost to food expenditures
# 0                                               42.5
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN

# %%
owid3 = pd.DataFrame(owid3)
owid4 = pd.DataFrame(owid4)

# merging owid3 & owid4
owid = pd.merge(owid3, owid4, how='inner')
owid
# Out:
#        Entity Code  Year  Number of people who cannot afford a healthy diet  \
# 0     Albania  ALB  2017                                           900000.0
# 1     Albania  ALB  2018                                           700000.0
# 2     Albania  ALB  2019                                           600000.0
# 3     Albania  ALB  2020                                           600000.0
# 4     Albania  ALB  2021                                           400000.0
# ..        ...  ...   ...                                                ...
# 758    Zambia  ZMB  2018                                         15700000.0
# 759    Zambia  ZMB  2019                                         16299999.0
# 760    Zambia  ZMB  2020                                         17000000.0
# 761    Zambia  ZMB  2021                                         17500000.0
# 762  Zimbabwe  ZWE  2017                                         10000000.0
#
# ...

# %%
# save the merged owid1 & owid2 DataFrame to a CSV file
owid_cost.to_csv('./our_world_in_data/owid_cost.csv')

# save the merged owid3 & owid4 DataFrame to a CSV file
owid.to_csv('./our_world_in_data/owid.csv')

# %%
owid_cost.shape
# Out:
# (885, 5)

# %%
owid.shape
# Out:
# (763, 5)

# %%
# merge owid & owid_cost

owid_final = pd.merge(owid_cost, owid, on=['Entity', 'Code', 'Year'], how='left')
owid_final = pd.DataFrame(owid_final)
owid_final.head()
# Out:
#     Entity Code  Year  Cost of a healthy diet  \
# 0  Albania  ALB  2017                   3.952
# 1  Albania  ALB  2018                   4.069
# 2  Albania  ALB  2019                   4.262
# 3  Albania  ALB  2020                   4.280
# 4  Albania  ALB  2021                   4.388
#
#    Affordability of a healthy diet: ratio of cost to food expenditures  \
# 0                                               42.5
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    Number of people who cannot afford a healthy diet  \
# 0                                           900000.0
# 1                                           700000.0
# 2                                           600000.0
# 3                                           600000.0
# 4                                           400000.0
#
# ...

# %%
owid_final.shape
# Out:
# (885, 7)

# %%
# save the merged owid & owid_cost DataFrame to a CSV file
owid_final.to_csv('./final_datasets/owid_final.csv', index=False)

# Now I have one csv file from the original 4 OWID datasets

# %% [markdown]
# # FAOSTAT DATA

# %%
fao_food_balance = pd.read_csv('./faostat/FoodBalanceSheets_2010-2021/FoodBalanceSheets.csv', encoding='ISO-8859-1')
fao_food_balance.head()
# Out:
#    Area Code Area Code (M49)         Area  Item Code Item Code (FBS)  \
# 0          2            '004  Afghanistan       2501          'S2501
# 1          2            '004  Afghanistan       2501          'S2501
# 2          3            '008      Albania       2501          'S2501
# 3          3            '008      Albania       2501          'S2501
# 4          2            '004  Afghanistan       2501          'S2501
#
#          Item  Element Code                        Element  Year Code  Year  \
# 0  Population           511  Total Population - Both sexes       2010  2010
# 1  Population           511  Total Population - Both sexes       2011  2011
# 2  Population           511  Total Population - Both sexes       2010  2010
# 3  Population           511  Total Population - Both sexes       2011  2011
# 4  Population           511  Total Population - Both sexes       2012  2012
#
#       Unit     Value Flag
# 0  1000 No  28189.67    X
# 1  1000 No  29249.16    X
# ...

# %%
fao_food_balance.shape #need to look up what "Value" means, in this case of top 5 it equals "511: Total Population - Both sexes"
# Out:
# (4320908, 13)

# %%
fao_food_balance.Item.unique()
# Out:
# array(['Population', 'Grand Total', 'Vegetal Products', 'Animal Products',
#        'Cereals - Excluding Beer', 'Wheat and products', 'Animal fats',
#        'Fish, Body Oil', 'Fish, Liver Oil', 'Fish, Seafood',
#        'Freshwater Fish', 'Demersal Fish', 'Rice and products',
#        'Pelagic Fish', 'Marine Fish, Other', 'Crustaceans', 'Cephalopods',
#        'Barley and products', 'Molluscs, Other',
#        'Aquatic Animals, Others', 'Aquatic Products, Other',
#        'Aquatic Plants', 'Maize and products', 'Rye and products', 'Oats',
#        'Millet and products', 'Sorghum and products', 'Cereals, Other',
#        'Starchy Roots', 'Cassava and products', 'Potatoes and products',
#        'Sweet potatoes', 'Roots, Other', 'Sugar Crops', 'Sugar cane',
#        'Sugar & Sweeteners', 'Sugar (Raw Equivalent)', 'Yams',
#        'Sweeteners, Other', 'Honey', 'Pulses', 'Sugar beet', 'Beans',
#        'Peas', 'Pulses, Other and products', 'Treenuts',
# ...

# %%
fao_food_security = pd.read_csv('./faostat/Food_Security_Data/Food_Security_Data.csv', encoding='ISO-8859-1')
fao_food_security.head()
# Out:
# /var/folders/t9/v5s_2kk94772zxhn2dhj8f1m0000gn/T/ipykernel_13299/3174970700.py:1: DtypeWarning: Columns (12) have mixed types. Specify dtype option on import or set low_memory=False.
#   fao_food_security = pd.read_csv('./faostat/Food_Security_Data/Food_Security_Data.csv', encoding='ISO-8859-1')
#    Area Code Area Code (M49)         Area Item Code  \
# 0          2            '004  Afghanistan     21010
# 1          2            '004  Afghanistan     21010
# 2          2            '004  Afghanistan     21010
# 3          2            '004  Afghanistan     21010
# 4          2            '004  Afghanistan     21010
#
#                                                 Item  Element Code Element  \
# 0  Average dietary energy supply adequacy (percen...          6121   Value
# 1  Average dietary energy supply adequacy (percen...          6121   Value
# 2  Average dietary energy supply adequacy (percen...          6121   Value
# ...

# %%
fao_food_security.shape
# Out:
# (233305, 13)

# %%
fao_food_security.Item.nunique()
# Out:
# 68

# %%
fao_food_security.Item.unique()
# Out:
# array(['Average dietary energy supply adequacy (percent) (3-year average)',
#        'Share of dietary energy supply derived from cereals, roots and tubers (kcal/cap/day) (3-year average)',
#        'Average protein supply (g/cap/day) (3-year average)',
#        'Average supply of protein of animal origin (g/cap/day) (3-year average)',
#        'Gross domestic product per capita, PPP, (constant 2017 international $)',
#        'Prevalence of undernourishment (percent) (3-year average)',
#        'Number of people undernourished (million) (3-year average)',
#        'Prevalence of severe food insecurity in the total population (percent) (3-year average)',
#        'Prevalence of severe food insecurity in the male adult population (percent) (3-year average)',
#        'Prevalence of severe food insecurity in the female adult population (percent) (3-year average)',
#        'Prevalence of moderate or severe food insecurity in the total population (percent) (3-year average)',
# ...

# %%
fao_coahd = pd.read_csv('./faostat/Cost_Affordability_Healthy_Diet_CoAHD/Cost_Affordability_Healthy_Diet_CoAHD.csv', encoding='ISO-8859-1')
fao_coahd.head()
# Out:
#    Area Code Area Code (M49)     Area  Item Code  \
# 0          3            '008  Albania       7004
# 1          3            '008  Albania       7004
# 2          3            '008  Albania       7004
# 3          3            '008  Albania       7004
# 4          3            '008  Albania       7004
#
#                                                 Item  Element Code Element  \
# 0  Cost of a healthy diet (PPP dollar per person ...          6226   Value
# 1  Cost of a healthy diet (PPP dollar per person ...          6226   Value
# 2  Cost of a healthy diet (PPP dollar per person ...          6226   Value
# 3  Cost of a healthy diet (PPP dollar per person ...          6226   Value
# 4  Cost of a healthy diet (PPP dollar per person ...          6226   Value
#
#    Year Code  Year                           Unit  Value Flag
# 0       2017  2017  PPP dollar per person per day  3.952    E
# 1       2018  2018  PPP dollar per person per day  4.069    E
# ...

# %%
fao_coahd.shape # could I combine this with the OWID datasets?
# Out:
# (4590, 12)

# %%
fao_coahd.Item.unique()
# Out:
# array(['Cost of a healthy diet (PPP dollar per person per day)',
#        'Cost of starchy staples', 'Cost of animal source foods',
#        'Cost of legumes, nuts and seeds', 'Cost of vegetables',
#        'Cost of fruits', 'Cost of oils and fats',
#        'Percentage of the population unable to afford a healthy diet (percent)',
#        'Number of people unable to afford a healthy diet (million)'],
#       dtype=object)

# %%
fao_cp = pd.read_csv('./faostat/Consumer_Price_Indices/Consumer_Price_Indices.csv')
fao_cp
# Out:
#        Domain Code                  Domain  Area Code (M49)         Area  \
# 0               CP  Consumer Price Indices                4  Afghanistan
# 1               CP  Consumer Price Indices                4  Afghanistan
# 2               CP  Consumer Price Indices                4  Afghanistan
# 3               CP  Consumer Price Indices                4  Afghanistan
# 4               CP  Consumer Price Indices                4  Afghanistan
# ...            ...                     ...              ...          ...
# 213745          CP  Consumer Price Indices                9      Oceania
# 213746          CP  Consumer Price Indices                9      Oceania
# 213747          CP  Consumer Price Indices                9      Oceania
# 213748          CP  Consumer Price Indices                9      Oceania
# 213749          CP  Consumer Price Indices                9      Oceania
#
#         Year Code  Year  Item Code  \
# 0            2000  2000      23013
# ...

# %%
fao_cp.Item.unique()
# Out:
# array(['Consumer Prices, Food Indices (2015 = 100)',
#        'Consumer Prices, General Indices (2015 = 100)',
#        'Food price inflation',
#        'Consumer Prices, Food Indices (2015 = 100), median',
#        'Consumer Prices, Food Indices (2015 = 100), weighted average',
#        'Consumer Prices, General Indices (2015 = 100), median',
#        'Consumer Prices, General Indices (2015 = 100), weighted average',
#        'Food price inflation, median',
#        'Food price inflation, weighted average'], dtype=object)

# %%
fao_cp.Year.unique()
# Out:
# array([2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010,
#        2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020, 2021,
#        2022, 2023])

# %%
fao_cp.shape
# Out:
# (213750, 17)

# %%
fao_food_prices = pd.read_csv('./faostat/Prices/Prices.csv', encoding='ISO-8859-1')
fao_food_prices
# Out:
#          Area Code Area Code (M49)         Area  Item Code Item Code (CPC)  \
# 0                2            '004  Afghanistan        221          '01371
# 1                2            '004  Afghanistan        221          '01371
# 2                2            '004  Afghanistan        221          '01371
# 3                2            '004  Afghanistan        221          '01371
# 4                2            '004  Afghanistan        221          '01371
# ...            ...             ...          ...        ...             ...
# 1194825        181            '716     Zimbabwe       1800          'F1800
# 1194826        181            '716     Zimbabwe       1800          'F1800
# 1194827        181            '716     Zimbabwe       1800          'F1800
# 1194828        181            '716     Zimbabwe       1800          'F1800
# 1194829        181            '716     Zimbabwe       1800          'F1800
#
#                              Item  Element Code  \
# ...

# %%
fao_food_prices.shape
# Out:
# (1194830, 15)

# %%
fao_food_prices.Item.unique()
# Out:
# array(['Almonds, in shell',
#        'Anise, badian, coriander, cumin, caraway, fennel and juniper berries, raw',
#        'Apples', 'Apricots', 'Barley', 'Cantaloupes and other melons',
#        'Cotton lint, ginned', 'Cotton seed', 'Figs',
#        'Game meat, fresh, chilled or frozen', 'Grapes',
#        'Hen eggs in shell, fresh', 'Linseed', 'Maize (corn)',
#        'Meat of camels, fresh or chilled',
#        'Meat of camels, fresh or chilled (biological)',
#        'Meat of cattle with the bone, fresh or chilled',
#        'Meat of cattle with the bone, fresh or chilled (biological)',
#        'Meat of chickens, fresh or chilled',
#        'Meat of chickens, fresh or chilled (biological)',
#        'Meat of goat, fresh or chilled',
#        'Meat of goat, fresh or chilled (biological)',
#        'Meat of sheep, fresh or chilled',
#        'Meat of sheep, fresh or chilled (biological)', 'Millet',
#        'Natural honey', 'Olives', 'Oranges', 'Other citrus fruit, n.e.c.',
# ...

# %% [markdown]
# Asking myself if I can merge any of the FAO datasets.. I do so further down this notebook under the Merging header.

# %% [markdown]
# # WORLD BANK DATA

# %%
wb_food_prices = pd.read_csv('./world_bank/Food_Prices_for_Nutrition/Food_Prices_for_Nutrition.csv', encoding='ISO-8859-1')
wb_food_prices.head()
# Out:
#              Classification Name Classification Code Country Name  \
# 0  Food Prices for Nutrition 1.0             FPN 1.0      Albania
# 1  Food Prices for Nutrition 1.0             FPN 1.0      Albania
# 2  Food Prices for Nutrition 1.0             FPN 1.0      Albania
# 3  Food Prices for Nutrition 1.0             FPN 1.0      Albania
# 4  Food Prices for Nutrition 1.0             FPN 1.0      Albania
#
#   Country Code    Time Time Code  \
# 0          ALB  2017.0    YR2017
# 1          ALB  2018.0    YR2018
# 2          ALB  2019.0    YR2019
# 3          ALB  2020.0    YR2020
# 4          ALB  2021.0    YR2021
#
#   Affordability of a healthy diet: ratio of cost to food expenditures [CoHD_fexp]  \
# 0                                              0.425
# 1                                                 ..
# 2                                                 ..
# 3                                                 ..
# 4                                                 ..
#
# ...

# %%
wb_food_prices.shape
# Out:
# (3725, 40)

# %%
wb_food_prices.Time.unique()
# Out:
# array([2017., 2018., 2019., 2020., 2021.,   nan])

# %%
wb_food_prices.columns
# Out:
# Index(['Classification Name', 'Classification Code', 'Country Name',
#        'Country Code', 'Time', 'Time Code',
#        'Affordability of a healthy diet: ratio of cost to food expenditures [CoHD_fexp]',
#        'Affordability of a healthy diet: ratio of cost to the food poverty line [CoHD_pov]',
#        'Affordability of a nutrient adequate diet: ratio of cost to food expenditures [CoNA_fexp]',
#        'Affordability of a nutrient adequate diet: ratio of cost to the food poverty line [CoNA_pov]',
#        'Affordability of an energy sufficient diet: ratio of cost to food expenditures [CoCA_fexp]',
#        'Affordability of an energy sufficient diet: ratio of cost to the food poverty line [CoCA_pov]',
#        'Cost of a healthy diet [CoHD]',
#        'Cost of a healthy diet relative to the cost of sufficient energy from starchy staples [CoHD_CoCA]',
#        'Cost of a nutrient adequate diet [CoNA]',
#        'Cost of an energy sufficient diet [CoCA]',
# ...

# %% [markdown]
# Some columns from: Cost_Affordability_Healthy_Diet_CoAHD.csv match World Bank's Food_Prices_for_Nutrition.csv
#
# 'Cost of a healthy diet (PPP dollar per person per day)',
# 'Cost of starchy staples', 'Cost of animal source foods',
# 'Cost of legumes, nuts and seeds', 'Cost of vegetables',
# 'Cost of fruits', 'Cost of oils and fats',
# 'Percentage of the population unable to afford a healthy diet (percent)',
# 'Number of people unable to afford a healthy diet (million)'

# %%
wb_food_prices2 = pd.read_csv('./world_bank/Food_Prices_for_Nutrition/Food_Prices_for_Nutrition_Series_Metadata.csv', encoding='ISO-8859-1')
wb_food_prices2.head()
# Out:
#              Classification Name Classification Code Country Name  \
# 0  Food Prices for Nutrition 1.0             FPN 1.0      Albania
# 1  Food Prices for Nutrition 1.0             FPN 1.0      Albania
# 2  Food Prices for Nutrition 1.0             FPN 1.0      Albania
# 3  Food Prices for Nutrition 1.0             FPN 1.0      Albania
# 4  Food Prices for Nutrition 1.0             FPN 1.0      Albania
#
#   Country Code    Time Time Code  \
# 0          ALB  2017.0    YR2017
# 1          ALB  2018.0    YR2018
# 2          ALB  2019.0    YR2019
# 3          ALB  2020.0    YR2020
# 4          ALB  2021.0    YR2021
#
#   Affordability of a healthy diet: ratio of cost to food expenditures [CoHD_fexp]  \
# 0                                              0.425
# 1                                                 ..
# 2                                                 ..
# 3                                                 ..
# 4                                                 ..
#
# ...

# %%
wb_food_prices2.shape
# Out:
# (3760, 40)

# %%
wb_food_prices2.Time.unique()
# Out:
# array([2017., 2018., 2019., 2020., 2021.,   nan])

# %%
# wb_food_prices and wb_food_prices2 are be the same. Decided to eliminate the metadata version

# %%
# World Bank food prices for nutrition data might be same as OWID

# %%
# PROB WONT USE THIS ONE
supply = pd.read_csv('./Misc Datasets/FAO/Supply_Utilization_Accounts_Food_and_Diet_E_All_Data_Normalized/Supply_Utilization_Accounts_Food_and_Diet_E_All_Data_Normalized.csv', encoding='ISO-8859-1')
supply.head()
# Out:
#    Area Code Area Code (M49)         Area Food Group Code       Food Group  \
# 0          2            '004  Afghanistan             FG0  All food groups
# 1          2            '004  Afghanistan             FG0  All food groups
# 2          2            '004  Afghanistan             FG0  All food groups
# 3          2            '004  Afghanistan             FG0  All food groups
# 4          2            '004  Afghanistan             FG0  All food groups
#
#    Indicator Code      Indicator  Element Code Element  Year Code  Year  \
# 0            4003  Energy supply          6128   Value       2010  2010
# 1            4003  Energy supply          6128   Value       2011  2011
# 2            4003  Energy supply          6128   Value       2012  2012
# 3            4003  Energy supply          6128   Value       2013  2013
# 4            4003  Energy supply          6128   Value       2014  2014
#
#          Unit   Value Flag Note
# 0  kcal/cap/d  2208.0    E  NaN
# ...

# %%
supply.shape
# Out:
# (669646, 15)

# %%
supply.Indicator.unique()
# Out:
# array(['Energy supply', 'Protein supply', 'Fat supply',
#        'Carbohydrate, available, supply', 'Dietary fibre supply',
#        'Calcium supply', 'Iron supply', 'Zinc supply', 'Magnesium supply',
#        'Phosphorus supply', 'Potassium supply', 'Thiamin supply',
#        'Riboflavin supply', 'Vitamin C supply', 'Vitamin A supply, in RE',
#        'Vitamin A supply, in RAE', 'Copper supply',
#        'Docosahexaenoic acid\xa0(DHA) supply', 'Vitamin B6 supply',
#        'Eicosapentaenoic acid (EPA) supply', 'Selenium supply',
#        'Vitamin B12 supply', 'Total saturated fatty acids supply',
#        'Total monounsaturated fatty acids supply',
#        'Total polyunsaturated fatty acids supply'], dtype=object)

# %% [markdown]
# # Merging

# %%
# Combine: 
#FAO - Cost_Affordability_Healthy_Diet_CoAHD.csv 
#with 
#OWID - owid_final.csv

#owid_final.rename(columns={'Entity':'Area'}, inplace=True)

# df.rename(columns={'old_column_name': 'new_column_name'}, inplace=True)

#coahd = pd.merge(fao_coahd, owid_final, on=['Area', 'Year'], how='left')
#coahd = pd.DataFrame(coahd)
#coahd.head()

# this didn't work

# %%
# Merge instead the following DataFrames/datasets: 
# All the FAO datasets:
#fao_food_balance
#fao_food_security
#fao_coahd
#fao_cp
#fao_food_prices

# %%
fao_food_balance.head(1)
# Out:
#    Area Code Area Code (M49)         Area  Item Code Item Code (FBS)  \
# 0          2            '004  Afghanistan       2501          'S2501
#
#          Item  Element Code                        Element  Year Code  Year  \
# 0  Population           511  Total Population - Both sexes       2010  2010
#
#       Unit     Value Flag
# 0  1000 No  28189.67    X

# %%
fao_food_security.head(1)
# Out:
#    Area Code Area Code (M49)         Area Item Code  \
# 0          2            '004  Afghanistan     21010
#
#                                                 Item  Element Code Element  \
# 0  Average dietary energy supply adequacy (percen...          6121   Value
#
#    Year Code       Year Unit Value Flag Note
# 0   20002002  2000-2002    %    88    E  NaN

# %%
fao_coahd.head(1)
# Out:
#    Area Code Area Code (M49)     Area  Item Code  \
# 0          3            '008  Albania       7004
#
#                                                 Item  Element Code Element  \
# 0  Cost of a healthy diet (PPP dollar per person ...          6226   Value
#
#    Year Code  Year                           Unit  Value Flag
# 0       2017  2017  PPP dollar per person per day  3.952    E

# %%
fao_coahd.dtypes
# Out:
# Area Code            int64
# Area Code (M49)     object
# Area                object
# Item Code            int64
# Item                object
# Element Code         int64
# Element             object
# Year Code            int64
# Year                 int64
# Unit                object
# Value              float64
# Flag                object
# dtype: object

# %%
fao_food_security.dtypes
# Out:
# Area Code           int64
# Area Code (M49)    object
# Area               object
# Item Code          object
# Item               object
# Element Code        int64
# Element            object
# Year Code           int64
# Year               object
# Unit               object
# Value              object
# Flag               object
# Note               object
# dtype: object

# %%
fao_food_security.shape
# Out:
# (233305, 13)

# %%
fao_coahd.shape
# Out:
# (4590, 12)

# %%
# now merge these 2

merged_fao = pd.concat([fao_food_security, fao_coahd], ignore_index=True)
merged_fao = pd.DataFrame(merged_fao)
merged_fao.head(1)
# Out:
#    Area Code Area Code (M49)         Area Item Code  \
# 0          2            '004  Afghanistan     21010
#
#                                                 Item  Element Code Element  \
# 0  Average dietary energy supply adequacy (percen...          6121   Value
#
#    Year Code       Year Unit Value Flag Note
# 0   20002002  2000-2002    %    88    E  NaN

# %%
merged_fao.to_csv('./final_datasets/merged_fao_food_security_and_cost_affordability_healthy_diet_coahd.csv', index=False)

# %%
merged_fao.shape
# Out:
# (237895, 13)

# %%
merged_fao.dtypes
# Out:
# Area Code           int64
# Area Code (M49)    object
# Area               object
# Item Code          object
# Item               object
# Element Code        int64
# Element            object
# Year Code           int64
# Year               object
# Unit               object
# Value              object
# Flag               object
# Note               object
# dtype: object
